# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | bengkulu
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | chicama
# Processing Record 7 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 1 | ketchikan
# Processing Record 9 of Set 1 | nanortalik
# Processing Record 10 of Set 1 | sankt georgen
# Processing Record 11 of Set 1 | nampula
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | broken hill
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | olafsvik
# Processing Record 17 of Set 1 | bathsheba
# Processing Record 18 of Set 1 | port macquarie
# Processing Record 19 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 1 | kropotkin
# Processing Record 21 of Set 1 | coquimbo
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | starodub
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | cabedelo
# Processing Record 26 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | svetlyy
# Processing Record 29 of Set 1 | great yarmouth
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | shahrud
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | saint cloud
# Processing Record 34 of Set 1 | monte alegre
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | fortuna
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | matay
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | goderich
# Processing Record 44 of Set 1 | san patricio
# Processing Record 45 of Set 1 | inhambane
# Processing Record 46 of Set 1 | monrovia
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | nicoya
# Processing Record 50 of Set 1 | maksi
# Processing Record 1 of Set 2 | qaqortoq
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | banjarmasin
# Processing Record 4 of Set 2 | mumford
# Processing Record 5 of Set 2 | kruisfontein
# Processing Record 6 of Set 2 | shaoguan
# Processing Record 7 of Set 2 | ayan
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | sao felix do xingu
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | cullera
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | yulara
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | laguna
# Processing Record 16 of Set 2 | namibe
# Processing Record 17 of Set 2 | jalu
# Processing Record 18 of Set 2 | palmer
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | moshupa
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | ilorin
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | kisangani
# Processing Record 25 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 2 | sinnamary
# Processing Record 27 of Set 2 | terney
# Processing Record 28 of Set 2 | bairiki
# Processing Record 29 of Set 2 | gravdal
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | methoni
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | airai
# Processing Record 35 of Set 2 | buin
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | katobu
# Processing Record 39 of Set 2 | ambatofinandrahana
# Processing Record 40 of Set 2 | mitsamiouli
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | rio grande
# Processing Record 43 of Set 2 | souillac
# Processing Record 44 of Set 2 | fort nelson
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | cherskiy
# Processing Record 47 of Set 2 | portland
# Processing Record 48 of Set 2 | bluff
# Processing Record 49 of Set 2 | ahipara
# Processing Record 50 of Set 2 | uaua
# Processing Record 1 of Set 3 | taseyevo
# Processing Record 2 of Set 3 | provideniya
# Processing Record 3 of Set 3 | the valley
# Processing Record 4 of Set 3 | husavik
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | almeirim
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | hobart
# Processing Record 9 of Set 3 | edinburg
# Processing Record 10 of Set 3 | korla
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | kapaa
# Processing Record 13 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | haines junction
# Processing Record 17 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 18 of Set 3 | burnie
# Processing Record 19 of Set 3 | half moon bay
# Processing Record 20 of Set 3 | port lavaca
# Processing Record 21 of Set 3 | rock hill
# Processing Record 22 of Set 3 | cockburn town
# Processing Record 23 of Set 3 | port lincoln
# Processing Record 24 of Set 3 | onda
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | nizhniy tsasuchey
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | takoradi
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | mogadishu
# Processing Record 32 of Set 3 | semnan
# Processing Record 33 of Set 3 | san jeronimo
# Processing Record 34 of Set 3 | sobolevo
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | yellowknife
# Processing Record 37 of Set 3 | lewisville
# Processing Record 38 of Set 3 | codrington
# Processing Record 39 of Set 3 | korsakov
# Processing Record 40 of Set 3 | vostok
# Processing Record 41 of Set 3 | berdigestyakh
# Processing Record 42 of Set 3 | sotnikovskoye
# Processing Record 43 of Set 3 | new norfolk
# Processing Record 44 of Set 3 | butaritari
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | los llanos de aridane
# Processing Record 47 of Set 3 | clyde river
# Processing Record 48 of Set 3 | kisumu
# Processing Record 49 of Set 3 | kampong thum
# Processing Record 50 of Set 3 | makakilo city
# Processing Record 1 of Set 4 | nouadhibou
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | hovd
# Processing Record 4 of Set 4 | bandarbeyla
# Processing Record 5 of Set 4 | milan
# Processing Record 6 of Set 4 | senanga
# Processing Record 7 of Set 4 | xifeng
# Processing Record 8 of Set 4 | bossangoa
# Processing Record 9 of Set 4 | grafton
# Processing Record 10 of Set 4 | touros
# Processing Record 11 of Set 4 | yelovo
# Processing Record 12 of Set 4 | grindavik
# Processing Record 13 of Set 4 | bethel
# Processing Record 14 of Set 4 | lakatoro
# Processing Record 15 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 4 | nara
# Processing Record 17 of Set 4 | louga
# Processing Record 18 of Set 4 | tikapur
# Processing Record 19 of Set 4 | arcata
# Processing Record 20 of Set 4 | sibolga
# Processing Record 21 of Set 4 | fuyu
# Processing Record 22 of Set 4 | barranca
# Processing Record 23 of Set 4 | porbandar
# Processing Record 24 of Set 4 | sur
# Processing Record 25 of Set 4 | towada
# Processing Record 26 of Set 4 | san cristobal
# Processing Record 27 of Set 4 | san andres
# Processing Record 28 of Set 4 | maningrida
# Processing Record 29 of Set 4 | mana
# Processing Record 30 of Set 4 | oxford
# Processing Record 31 of Set 4 | nabire
# Processing Record 32 of Set 4 | sitka
# Processing Record 33 of Set 4 | cabo san lucas
# Processing Record 34 of Set 4 | zonguldak
# Processing Record 35 of Set 4 | tabou
# Processing Record 36 of Set 4 | ponta do sol
# Processing Record 37 of Set 4 | srednekolymsk
# Processing Record 38 of Set 4 | trairi
# Processing Record 39 of Set 4 | luena
# Processing Record 40 of Set 4 | beirut
# Processing Record 41 of Set 4 | zelenogorskiy
# Processing Record 42 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | tateyama
# Processing Record 44 of Set 4 | comodoro rivadavia
# Processing Record 45 of Set 4 | bonavista
# Processing Record 46 of Set 4 | te anau
# Processing Record 47 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 48 of Set 4 | lata
# Processing Record 49 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 4 | faanui
# Processing Record 1 of Set 5 | xuddur
# Processing Record 2 of Set 5 | mecca
# Processing Record 3 of Set 5 | sechura
# Processing Record 4 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 5 of Set 5 | khasan
# Processing Record 6 of Set 5 | geraldton
# Processing Record 7 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 5 | lebu
# Processing Record 9 of Set 5 | verkhnevilyuysk
# Processing Record 10 of Set 5 | houston
# Processing Record 11 of Set 5 | nedjo
# Processing Record 12 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 5 | margate
# Processing Record 14 of Set 5 | qaanaaq
# Processing Record 15 of Set 5 | lorengau
# Processing Record 16 of Set 5 | port keats
# Processing Record 17 of Set 5 | bayan
# Processing Record 18 of Set 5 | tlaxiaco
# City not found. Skipping...
# Processing Record 19 of Set 5 | veraval
# Processing Record 20 of Set 5 | abu zabad
# Processing Record 21 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 5 | dingle
# Processing Record 23 of Set 5 | kysyl-syr
# Processing Record 24 of Set 5 | okhotsk
# Processing Record 25 of Set 5 | port blair
# Processing Record 26 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 5 | kahului
# Processing Record 28 of Set 5 | hithadhoo
# Processing Record 29 of Set 5 | arlit
# Processing Record 30 of Set 5 | cayenne
# Processing Record 31 of Set 5 | brainerd
# Processing Record 32 of Set 5 | naze
# Processing Record 33 of Set 5 | lavrentiya
# Processing Record 34 of Set 5 | mount gambier
# Processing Record 35 of Set 5 | pangnirtung
# Processing Record 36 of Set 5 | saskylakh
# Processing Record 37 of Set 5 | quesnel
# Processing Record 38 of Set 5 | georgetown
# Processing Record 39 of Set 5 | gushikawa
# Processing Record 40 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 41 of Set 5 | prince albert
# Processing Record 42 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 5 | rongcheng
# Processing Record 44 of Set 5 | maniitsoq
# Processing Record 45 of Set 5 | loanda
# Processing Record 46 of Set 5 | east london
# Processing Record 47 of Set 5 | vanimo
# Processing Record 48 of Set 5 | terra santa
# Processing Record 49 of Set 5 | praia da vitoria
# Processing Record 50 of Set 5 | ouesso
# Processing Record 1 of Set 6 | osakarovka
# Processing Record 2 of Set 6 | novoye atlashevo
# City not found. Skipping...
# Processing Record 3 of Set 6 | hervey bay
# Processing Record 4 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 6 | copala
# Processing Record 6 of Set 6 | cap malheureux
# Processing Record 7 of Set 6 | karpathos
# Processing Record 8 of Set 6 | avera
# Processing Record 9 of Set 6 | vardo
# Processing Record 10 of Set 6 | kashi
# Processing Record 11 of Set 6 | fasa
# Processing Record 12 of Set 6 | kapoeta
# Processing Record 13 of Set 6 | ribeira grande
# Processing Record 14 of Set 6 | grand gaube
# Processing Record 15 of Set 6 | tuatapere
# Processing Record 16 of Set 6 | nemuro
# Processing Record 17 of Set 6 | itarema
# Processing Record 18 of Set 6 | walvis bay
# Processing Record 19 of Set 6 | pacific grove
# Processing Record 20 of Set 6 | sanchor
# Processing Record 21 of Set 6 | celestun
# Processing Record 22 of Set 6 | san policarpo
# Processing Record 23 of Set 6 | umm lajj
# Processing Record 24 of Set 6 | genhe
# Processing Record 25 of Set 6 | ilulissat
# Processing Record 26 of Set 6 | keetmanshoop
# Processing Record 27 of Set 6 | lichinga
# Processing Record 28 of Set 6 | baijiantan
# Processing Record 29 of Set 6 | ceres
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | matara
# Processing Record 33 of Set 6 | novyy urgal
# Processing Record 34 of Set 6 | miyako
# Processing Record 35 of Set 6 | dunedin
# Processing Record 36 of Set 6 | ancud
# Processing Record 37 of Set 6 | dehloran
# Processing Record 38 of Set 6 | lagoa
# Processing Record 39 of Set 6 | tomatlan
# Processing Record 40 of Set 6 | guerrero negro
# Processing Record 41 of Set 6 | longyearbyen
# Processing Record 42 of Set 6 | poronaysk
# Processing Record 43 of Set 6 | flinders
# Processing Record 44 of Set 6 | beloha
# Processing Record 45 of Set 6 | bay roberts
# Processing Record 46 of Set 6 | san rafael
# Processing Record 47 of Set 6 | sambava
# Processing Record 48 of Set 6 | maumere
# Processing Record 49 of Set 6 | kieta
# Processing Record 50 of Set 6 | sarangani
# Processing Record 1 of Set 7 | gat
# Processing Record 2 of Set 7 | dubbo
# Processing Record 3 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 7 | port moresby
# Processing Record 5 of Set 7 | paracuru
# Processing Record 6 of Set 7 | channel-port aux basques
# Processing Record 7 of Set 7 | kibaya
# Processing Record 8 of Set 7 | yumen
# Processing Record 9 of Set 7 | hecun
# Processing Record 10 of Set 7 | merauke
# Processing Record 11 of Set 7 | fallon
# Processing Record 12 of Set 7 | acari
# Processing Record 13 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 7 | tahe
# Processing Record 15 of Set 7 | brownsville
# Processing Record 16 of Set 7 | sarai
# Processing Record 17 of Set 7 | kalabo
# Processing Record 18 of Set 7 | qandala
# Processing Record 19 of Set 7 | tiksi
# Processing Record 20 of Set 7 | san jose
# Processing Record 21 of Set 7 | acapulco
# Processing Record 22 of Set 7 | quimper
# Processing Record 23 of Set 7 | katsuura
# Processing Record 24 of Set 7 | bongor
# Processing Record 25 of Set 7 | khani
# Processing Record 26 of Set 7 | vasylivka
# Processing Record 27 of Set 7 | mikhaylovka
# Processing Record 28 of Set 7 | novomikhaylovskiy
# Processing Record 29 of Set 7 | lompoc
# Processing Record 30 of Set 7 | teya
# Processing Record 31 of Set 7 | mount isa
# Processing Record 32 of Set 7 | galle
# Processing Record 33 of Set 7 | bethanien
# Processing Record 34 of Set 7 | alice springs
# Processing Record 35 of Set 7 | san carlos de bariloche
# Processing Record 36 of Set 7 | dukat
# Processing Record 37 of Set 7 | khandyga
# Processing Record 38 of Set 7 | vesyegonsk
# Processing Record 39 of Set 7 | atar
# Processing Record 40 of Set 7 | novobirilyussy
# Processing Record 41 of Set 7 | krasnorechenskiy
# Processing Record 42 of Set 7 | huarmey
# Processing Record 43 of Set 7 | fukue
# Processing Record 44 of Set 7 | wilmington
# Processing Record 45 of Set 7 | nueva loja
# Processing Record 46 of Set 7 | darlington
# Processing Record 47 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 48 of Set 7 | sungaipenuh
# Processing Record 49 of Set 7 | rincon
# Processing Record 50 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 8 | talnakh
# Processing Record 2 of Set 8 | najran
# Processing Record 3 of Set 8 | itoman
# Processing Record 4 of Set 8 | awbari
# Processing Record 5 of Set 8 | staraya poltavka
# Processing Record 6 of Set 8 | tortoli
# Processing Record 7 of Set 8 | tazovskiy
# Processing Record 8 of Set 8 | la grande
# Processing Record 9 of Set 8 | waddan
# Processing Record 10 of Set 8 | bubaque
# Processing Record 11 of Set 8 | kasongo-lunda
# Processing Record 12 of Set 8 | dawlatabad
# Processing Record 13 of Set 8 | faya
# Processing Record 14 of Set 8 | los algarrobos
# Processing Record 15 of Set 8 | dengzhou
# Processing Record 16 of Set 8 | tall kayf
# Processing Record 17 of Set 8 | severo-yeniseyskiy
# Processing Record 18 of Set 8 | kavaratti
# Processing Record 19 of Set 8 | iqaluit
# Processing Record 20 of Set 8 | pokrovsk
# Processing Record 21 of Set 8 | lodja
# Processing Record 22 of Set 8 | yunyang
# Processing Record 23 of Set 8 | urucara
# Processing Record 24 of Set 8 | ust-nera
# Processing Record 25 of Set 8 | port hedland
# Processing Record 26 of Set 8 | dergachi
# Processing Record 27 of Set 8 | wattegama
# Processing Record 28 of Set 8 | coruripe
# Processing Record 29 of Set 8 | umm kaddadah
# Processing Record 30 of Set 8 | bilma
# Processing Record 31 of Set 8 | port hueneme
# Processing Record 32 of Set 8 | axim
# Processing Record 33 of Set 8 | high level
# Processing Record 34 of Set 8 | saint-pierre
# Processing Record 35 of Set 8 | dongsheng
# Processing Record 36 of Set 8 | parana
# Processing Record 37 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 38 of Set 8 | berlevag
# Processing Record 39 of Set 8 | sao francisco
# Processing Record 40 of Set 8 | mwinilunga
# Processing Record 41 of Set 8 | qiyang
# Processing Record 42 of Set 8 | bongaree
# Processing Record 43 of Set 8 | asau
# Processing Record 44 of Set 8 | sogdiondon
# City not found. Skipping...
# Processing Record 45 of Set 8 | makasar
# Processing Record 46 of Set 8 | mariakani
# Processing Record 47 of Set 8 | narsaq
# Processing Record 48 of Set 8 | sao filipe
# Processing Record 49 of Set 8 | scottsbluff
# Processing Record 50 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 2 of Set 9 | swellendam
# Processing Record 3 of Set 9 | seoul
# Processing Record 4 of Set 9 | kalaleh
# Processing Record 5 of Set 9 | roma
# Processing Record 6 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 7 of Set 9 | flin flon
# Processing Record 8 of Set 9 | northam
# Processing Record 9 of Set 9 | basco
# Processing Record 10 of Set 9 | blackfoot
# Processing Record 11 of Set 9 | urusha
# Processing Record 12 of Set 9 | ostrovnoy
# Processing Record 13 of Set 9 | ha tinh
# Processing Record 14 of Set 9 | kirakira
# Processing Record 15 of Set 9 | le moule
# Processing Record 16 of Set 9 | chumikan
# Processing Record 17 of Set 9 | syracuse
# Processing Record 18 of Set 9 | la asuncion
# Processing Record 19 of Set 9 | sao gabriel da cachoeira
# Processing Record 20 of Set 9 | kupang
# Processing Record 21 of Set 9 | kalengwa
# Processing Record 22 of Set 9 | starominskaya
# Processing Record 23 of Set 9 | anshan
# Processing Record 24 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 25 of Set 9 | tura
# Processing Record 26 of Set 9 | ampanihy
# Processing Record 27 of Set 9 | dunmore east
# Processing Record 28 of Set 9 | berbera
# Processing Record 29 of Set 9 | necochea
# Processing Record 30 of Set 9 | tupiza
# Processing Record 31 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 9 | zhezkazgan
# Processing Record 33 of Set 9 | cervo
# Processing Record 34 of Set 9 | tomigusuku
# Processing Record 35 of Set 9 | mizoch
# Processing Record 36 of Set 9 | taoudenni
# Processing Record 37 of Set 9 | kosh-agach
# Processing Record 38 of Set 9 | lasa
# Processing Record 39 of Set 9 | tarazona
# Processing Record 40 of Set 9 | hamilton
# Processing Record 41 of Set 9 | quatre cocos
# Processing Record 42 of Set 9 | shimoda
# Processing Record 43 of Set 9 | hofn
# Processing Record 44 of Set 9 | leningradskiy
# Processing Record 45 of Set 9 | mbaiki
# Processing Record 46 of Set 9 | campbellton
# Processing Record 47 of Set 9 | vila velha
# Processing Record 48 of Set 9 | obidos
# Processing Record 49 of Set 9 | richards bay
# Processing Record 50 of Set 9 | tarnobrzeg
# Processing Record 1 of Set 10 | hopatcong
# Processing Record 2 of Set 10 | new plymouth
# Processing Record 3 of Set 10 | pochutla
# Processing Record 4 of Set 10 | abnub
# Processing Record 5 of Set 10 | byron bay
# Processing Record 6 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 7 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 10 | pecos
# Processing Record 9 of Set 10 | pingshan
# Processing Record 10 of Set 10 | whitley bay
# Processing Record 11 of Set 10 | masvingo
# Processing Record 12 of Set 10 | aldan
# Processing Record 13 of Set 10 | ginir
# Processing Record 14 of Set 10 | la ronge
# Processing Record 15 of Set 10 | alyangula
# Processing Record 16 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 10 | ambilobe
# Processing Record 18 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 19 of Set 10 | tumarbong
# Processing Record 20 of Set 10 | apatity
# Processing Record 21 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 22 of Set 10 | karratha
# Processing Record 23 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 10 | esperance
# Processing Record 25 of Set 10 | sao joao
# Processing Record 26 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 10 | dimbokro
# Processing Record 28 of Set 10 | rubtsovsk
# Processing Record 29 of Set 10 | abha
# Processing Record 30 of Set 10 | uruzgan
# Processing Record 31 of Set 10 | oyek
# Processing Record 32 of Set 10 | akyab
# Processing Record 33 of Set 10 | chardara
# Processing Record 34 of Set 10 | tabas
# Processing Record 35 of Set 10 | ha giang
# Processing Record 36 of Set 10 | sola
# Processing Record 37 of Set 10 | coracora
# Processing Record 38 of Set 10 | aljezur
# Processing Record 39 of Set 10 | shitanjing
# Processing Record 40 of Set 10 | jardim
# Processing Record 41 of Set 10 | greenville
# Processing Record 42 of Set 10 | garissa
# Processing Record 43 of Set 10 | calabozo
# Processing Record 44 of Set 10 | kuroiso
# Processing Record 45 of Set 10 | eyl
# Processing Record 46 of Set 10 | thinadhoo
# Processing Record 47 of Set 10 | kenai
# Processing Record 48 of Set 10 | abu dhabi
# Processing Record 49 of Set 10 | groa
# Processing Record 50 of Set 10 | adeje
# Processing Record 1 of Set 11 | general roca
# Processing Record 2 of Set 11 | baiyin
# Processing Record 3 of Set 11 | mumbwa
# Processing Record 4 of Set 11 | kindu
# Processing Record 5 of Set 11 | praia
# Processing Record 6 of Set 11 | moranbah
# Processing Record 7 of Set 11 | amravati
# Processing Record 8 of Set 11 | cidreira
# Processing Record 9 of Set 11 | batemans bay
# Processing Record 10 of Set 11 | menongue
# Processing Record 11 of Set 11 | kununurra
# Processing Record 12 of Set 11 | manokwari
# Processing Record 13 of Set 11 | sakaiminato
# Processing Record 14 of Set 11 | chapais
# Processing Record 15 of Set 11 | ikalamavony
# Processing Record 16 of Set 11 | thunder bay
# Processing Record 17 of Set 11 | wanaka
# Processing Record 18 of Set 11 | ahero
# Processing Record 19 of Set 11 | presidencia roque saenz pena
# Processing Record 20 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 11 | lere
# Processing Record 22 of Set 11 | porto novo
# Processing Record 23 of Set 11 | bria
# Processing Record 24 of Set 11 | mehamn
# Processing Record 25 of Set 11 | orotukan
# Processing Record 26 of Set 11 | port hardy
# Processing Record 27 of Set 11 | isangel
# Processing Record 28 of Set 11 | lubango
# Processing Record 29 of Set 11 | boa vista
# Processing Record 30 of Set 11 | henties bay
# Processing Record 31 of Set 11 | balykshi
# Processing Record 32 of Set 11 | ossora
# Processing Record 33 of Set 11 | muros
# Processing Record 34 of Set 11 | acobamba
# Processing Record 35 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 11 | firovo
# Processing Record 37 of Set 11 | alexandria
# Processing Record 38 of Set 11 | robe
# Processing Record 39 of Set 11 | gordeyevka
# Processing Record 40 of Set 11 | vestmannaeyjar
# Processing Record 41 of Set 11 | samus
# Processing Record 42 of Set 11 | mansa
# Processing Record 43 of Set 11 | chaman
# Processing Record 44 of Set 11 | swan hill
# Processing Record 45 of Set 11 | taltal
# Processing Record 46 of Set 11 | kerman
# Processing Record 47 of Set 11 | caravelas
# Processing Record 48 of Set 11 | rio claro
# Processing Record 49 of Set 11 | kerema
# Processing Record 50 of Set 11 | gogrial
# Processing Record 1 of Set 12 | kanungu
# Processing Record 2 of Set 12 | marica
# Processing Record 3 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 4 of Set 12 | terrasini
# Processing Record 5 of Set 12 | yeppoon
# Processing Record 6 of Set 12 | zhangjiakou
# Processing Record 7 of Set 12 | bathurst
# Processing Record 8 of Set 12 | noshiro
# Processing Record 9 of Set 12 | imbituba
# Processing Record 10 of Set 12 | constitucion
# Processing Record 11 of Set 12 | deep river
# Processing Record 12 of Set 12 | labuhan
# Processing Record 13 of Set 12 | nome
# Processing Record 14 of Set 12 | darnah
# Processing Record 15 of Set 12 | kalokhorion
# City not found. Skipping...
# Processing Record 16 of Set 12 | carmen
# Processing Record 17 of Set 12 | trelew
# Processing Record 18 of Set 12 | manoel urbano
# Processing Record 19 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 20 of Set 12 | plerin
# Processing Record 21 of Set 12 | teshie
# Processing Record 22 of Set 12 | hobyo
# Processing Record 23 of Set 12 | inta
# Processing Record 24 of Set 12 | pisco
# Processing Record 25 of Set 12 | saint-joseph
# Processing Record 26 of Set 12 | tucuman
# Processing Record 27 of Set 12 | ambajogai
# Processing Record 28 of Set 12 | macherla
# Processing Record 29 of Set 12 | zhifang
# Processing Record 30 of Set 12 | alofi
# Processing Record 31 of Set 12 | champasak
# Processing Record 32 of Set 12 | fecamp
# Processing Record 33 of Set 12 | caninde
# Processing Record 34 of Set 12 | carutapera
# Processing Record 35 of Set 12 | namatanai
# Processing Record 36 of Set 12 | koslan
# Processing Record 37 of Set 12 | huadian
# Processing Record 38 of Set 12 | askino
# Processing Record 39 of Set 12 | saint-jean-de-maurienne
# Processing Record 40 of Set 12 | fandriana
# Processing Record 41 of Set 12 | tilichiki
# Processing Record 42 of Set 12 | ust-ishim
# Processing Record 43 of Set 12 | cabra
# Processing Record 44 of Set 12 | komatipoort
# Processing Record 45 of Set 12 | irece
# Processing Record 46 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 12 | vytegra
# Processing Record 48 of Set 12 | port augusta
# Processing Record 49 of Set 12 | plettenberg bay
# Processing Record 50 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 13 | itamaraca
# Processing Record 2 of Set 13 | abilene
# Processing Record 3 of Set 13 | lensk
# Processing Record 4 of Set 13 | mokhotlong
# Processing Record 5 of Set 13 | alibag
# Processing Record 6 of Set 13 | tessalit
# Processing Record 7 of Set 13 | alihe
# Processing Record 8 of Set 13 | zyryanka
# Processing Record 9 of Set 13 | chimoio
# Processing Record 10 of Set 13 | brae
# Processing Record 11 of Set 13 | auki
# Processing Record 12 of Set 13 | ranong
# Processing Record 13 of Set 13 | atambua
# Processing Record 14 of Set 13 | freetown
# Processing Record 15 of Set 13 | puerto escondido
# Processing Record 16 of Set 13 | nyurba
# Processing Record 17 of Set 13 | paisley
# Processing Record 18 of Set 13 | basoda
# Processing Record 19 of Set 13 | santa lucia
# Processing Record 20 of Set 13 | westport
# Processing Record 21 of Set 13 | chiang khong
# Processing Record 22 of Set 13 | itupiranga
# Processing Record 23 of Set 13 | kezmarok
# Processing Record 24 of Set 13 | ajaccio
# Processing Record 25 of Set 13 | calamar
# Processing Record 26 of Set 13 | baghdad
# Processing Record 27 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 28 of Set 13 | pullman
# Processing Record 29 of Set 13 | ulladulla
# Processing Record 30 of Set 13 | newark
# Processing Record 31 of Set 13 | totness
# Processing Record 32 of Set 13 | mao
# Processing Record 33 of Set 13 | marawi
# Processing Record 34 of Set 13 | halifax
# Processing Record 35 of Set 13 | wangqing
# Processing Record 36 of Set 13 | tezu
# Processing Record 37 of Set 13 | san quintin
# Processing Record 38 of Set 13 | emerald
# Processing Record 39 of Set 13 | vredendal
# Processing Record 40 of Set 13 | komsomolskiy
# Processing Record 41 of Set 13 | huambo
# Processing Record 42 of Set 13 | puertollano
# Processing Record 43 of Set 13 | la crosse
# Processing Record 44 of Set 13 | san buenaventura
# Processing Record 45 of Set 13 | sao miguel do araguaia
# Processing Record 46 of Set 13 | barabinsk
# Processing Record 47 of Set 13 | hami
# Processing Record 48 of Set 13 | severnyy
# Processing Record 49 of Set 13 | katha
# City not found. Skipping...
# Processing Record 50 of Set 13 | ilinka
# City not found. Skipping...
# Processing Record 1 of Set 14 | bereda
# Processing Record 2 of Set 14 | penarroya-pueblonuevo
# Processing Record 3 of Set 14 | tumaco
# Processing Record 4 of Set 14 | mayumba
# Processing Record 5 of Set 14 | khotiv
# Processing Record 6 of Set 14 | durazno
# Processing Record 7 of Set 14 | fairbanks
# Processing Record 8 of Set 14 | algiers
# Processing Record 9 of Set 14 | bento goncalves
# Processing Record 10 of Set 14 | deputatskiy
# Processing Record 11 of Set 14 | wasilla
# Processing Record 12 of Set 14 | rabaul
# Processing Record 13 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 14 of Set 14 | popondetta
# Processing Record 15 of Set 14 | dickinson
# Processing Record 16 of Set 14 | lieksa
# Processing Record 17 of Set 14 | bardsir
# Processing Record 18 of Set 14 | madang
# Processing Record 19 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 14 | andenes
# Processing Record 21 of Set 14 | saurimo
# Processing Record 22 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 14 | subate
# Processing Record 24 of Set 14 | groningen
# Processing Record 25 of Set 14 | gazanjyk
# Processing Record 26 of Set 14 | fort morgan
# Processing Record 27 of Set 14 | waipawa
# Processing Record 28 of Set 14 | vao
# Processing Record 29 of Set 14 | morant bay
# Processing Record 30 of Set 14 | salamanca
# Processing Record 31 of Set 14 | hirara
# Processing Record 32 of Set 14 | pailon
# Processing Record 33 of Set 14 | aripuana
# Processing Record 34 of Set 14 | maceio
# Processing Record 35 of Set 14 | along
# Processing Record 36 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 37 of Set 14 | punta de piedra
# Processing Record 38 of Set 14 | cam ranh
# Processing Record 39 of Set 14 | pelym
# Processing Record 40 of Set 14 | leh
# Processing Record 41 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 14 | ramtek
# Processing Record 43 of Set 14 | valparaiso
# Processing Record 44 of Set 14 | daru
# Processing Record 45 of Set 14 | marystown
# Processing Record 46 of Set 14 | saint-louis
# Processing Record 47 of Set 14 | nong han
# Processing Record 48 of Set 14 | port-cartier
# Processing Record 49 of Set 14 | grand baie
# Processing Record 50 of Set 14 | auray
# Processing Record 1 of Set 15 | yatou
# Processing Record 2 of Set 15 | hudiksvall
# Processing Record 3 of Set 15 | padang
# Processing Record 4 of Set 15 | llano largo
# Processing Record 5 of Set 15 | kuusamo
# Processing Record 6 of Set 15 | vila franca do campo
# Processing Record 7 of Set 15 | santa rosa
# Processing Record 8 of Set 15 | silopi
# Processing Record 9 of Set 15 | camocim
# Processing Record 10 of Set 15 | urla
# Processing Record 11 of Set 15 | gavrilovka vtoraya
# Processing Record 12 of Set 15 | ternate
# Processing Record 13 of Set 15 | salalah
# Processing Record 14 of Set 15 | point pedro
# Processing Record 15 of Set 15 | mujiayingzi
# Processing Record 16 of Set 15 | nurlat
# Processing Record 17 of Set 15 | tambul
# City not found. Skipping...
# Processing Record 18 of Set 15 | cangzhou
# Processing Record 19 of Set 15 | liuzhou
# Processing Record 20 of Set 15 | san luis
# Processing Record 21 of Set 15 | chapayevka
# Processing Record 22 of Set 15 | sloboda
# Processing Record 23 of Set 15 | arak
# Processing Record 24 of Set 15 | dawan
# Processing Record 25 of Set 15 | kikwit
# Processing Record 26 of Set 15 | bintulu
# Processing Record 27 of Set 15 | palmerston
# Processing Record 28 of Set 15 | daxian
# City not found. Skipping...
# Processing Record 29 of Set 15 | beziers
# Processing Record 30 of Set 15 | cuenca
# Processing Record 31 of Set 15 | paz de ariporo
# City not found. Skipping...
# Processing Record 32 of Set 15 | warrington
# Processing Record 33 of Set 15 | burica
# City not found. Skipping...
# Processing Record 34 of Set 15 | ixtapa
# Processing Record 35 of Set 15 | bosaso
# Processing Record 36 of Set 15 | johi
# Processing Record 37 of Set 15 | fatehabad
# Processing Record 38 of Set 15 | niksic
# Processing Record 39 of Set 15 | kodinsk
# Processing Record 40 of Set 15 | luanda
# Processing Record 41 of Set 15 | tautira
# Processing Record 42 of Set 15 | nalobikha
# Processing Record 43 of Set 15 | acarau
# Processing Record 44 of Set 15 | sokoni
# Processing Record 45 of Set 15 | henderson
# Processing Record 46 of Set 15 | faruka
# Processing Record 47 of Set 15 | bunol
# Processing Record 48 of Set 15 | gueret
# Processing Record 49 of Set 15 | tondano
# Processing Record 50 of Set 15 | hambantota
# Processing Record 1 of Set 16 | ariquemes
# Processing Record 2 of Set 16 | alekseyevsk
# Processing Record 3 of Set 16 | road town
# Processing Record 4 of Set 16 | sussex
# Processing Record 5 of Set 16 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 16 | rudnyy
# Processing Record 7 of Set 16 | bonthe
# Processing Record 8 of Set 16 | porto walter
# Processing Record 9 of Set 16 | kirillov
# Processing Record 10 of Set 16 | santa maria del oro
# Processing Record 11 of Set 16 | moerai
# Processing Record 12 of Set 16 | giurgita
# Processing Record 13 of Set 16 | sistranda
# Processing Record 14 of Set 16 | balabac
# Processing Record 15 of Set 16 | khorixas
# Processing Record 16 of Set 16 | mogok
# Processing Record 17 of Set 16 | lagos
# Processing Record 18 of Set 16 | novorzhev
# Processing Record 19 of Set 16 | nova olinda do norte
# Processing Record 20 of Set 16 | baran
# Processing Record 21 of Set 16 | kosovo polje
# Processing Record 22 of Set 16 | khartoum
# Processing Record 23 of Set 16 | tiznit
# Processing Record 24 of Set 16 | mabaruma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 714

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Rikitea      PF -23.1203 -134.9692     78.30        79         100
# 1       Bengkulu      ID  -3.8004  102.2655     75.11        91          92
# 2           Hilo      US  19.7297 -155.0900     78.12        78           2
# 3      Cape Town      ZA -33.9258   18.4232     71.10        76           0
# 4        Chicama      PE  -7.8447  -79.1469     70.34        67          46
# 5      Ketchikan      US  55.3422 -131.6461     41.97        95         100
# 6     Nanortalik      GL  60.1432  -45.2371     19.17        78         100
# 7  Sankt Georgen      HU  47.1425   16.5815     34.70        67         100
# 8        Nampula      MZ -15.1165   39.2666     71.55        94          75
# 9  Mar Del Plata      AR -38.0023  -57.5575     78.01        36           0
#
#    Wind Speed Current Description
# 0       18.97     overcast clouds
# 1        4.03          light rain
# 2        5.99           clear sky
# 3        1.01           clear sky
# 4        7.27    scattered clouds
# 5       23.17       moderate rain
# 6       34.85     overcast clouds
# 7        1.90     overcast clouds
# 8       10.36          light rain
# 9        5.99           clear sky

# %%
output_data_file = "/Users/barbu/OneDrive/Documents/BOOTCAMP-APIs Module 6/Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
